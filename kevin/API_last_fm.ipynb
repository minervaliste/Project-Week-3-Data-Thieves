# %%
import requests
import pandas as pd
import json

# %%
USER_AGENT='Dataquest'
API_KEY= '0e183e26124cc0cca49ce5e97cad2811'

headers = {'user-agent': 'Dataquest'}
payload = {'api_key': API_KEY,
    'method': 'chart.gettopartists',
    'format': 'json',
    'country': 'Spain'
}
r = requests.get('http://ws.audioscrobbler.com/2.0/', headers=headers, params=payload)
result=r.json()

# %%
result['artists']['artist'][1]['name']
# Out:
# 'The Weeknd'

# %%
artist_list=[]
for i in range (len(result['artists']['artist'])):
                artist_list.append(result['artists']['artist'][i]['name'])
print(artist_list)
# Out:
# ['Billie Eilish', 'The Weeknd', 'Eminem', 'Kanye West', 'Post Malone', 'Ariana Grande', 'Lana Del Rey', 'Tame Impala', 'Dua Lipa', 'Halsey', 'Kendrick Lamar', 'Radiohead', 'The Beatles', 'Queen', 'David Bowie', 'Drake', 'Taylor Swift', 'Tyler, the Creator', 'Rihanna', 'Ed Sheeran', 'Mac Miller', 'Selena Gomez', 'Frank Ocean', 'Coldplay', 'Arctic Monkeys', 'Harry Styles', 'Gorillaz', 'Lady Gaga', 'Travi$ Scott', 'Beyoncé', 'Red Hot Chili Peppers', 'Calvin Harris', 'Maroon 5', 'Lorde', 'Justin Bieber', 'BROCKHAMPTON', 'Pink Floyd', 'Katy Perry', 'Fleetwood Mac', 'Green Day', 'Miley Cyrus', 'Childish Gambino', 'Nirvana', 'Future', 'Panic! at the Disco', 'Lizzo', 'Khalid', 'Roddy Ricch', 'Imagine Dragons', 'Sia']

# %%
serie_artists=pd.Series(artist_list)
serie_artists
# Out:
# 0             Billie Eilish
# 1                The Weeknd
# 2                    Eminem
# 3                Kanye West
# 4               Post Malone
# 5             Ariana Grande
# 6              Lana Del Rey
# 7               Tame Impala
# 8                  Dua Lipa
# 9                    Halsey
# 10           Kendrick Lamar
# 11                Radiohead
# 12              The Beatles
# 13                    Queen
# 14              David Bowie
# 15                    Drake
# 16             Taylor Swift
# 17       Tyler, the Creator
# 18                  Rihanna
# 19               Ed Sheeran
# 20               Mac Miller
# 21             Selena Gomez
# 22              Frank Ocean
# 23                 Coldplay
# 24           Arctic Monkeys
# 25             Harry Styles
# 26                 Gorillaz
# 27                Lady Gaga
# 28             Travi$ Scott
# 29                  Beyoncé
# 30    Red Hot Chili Peppers
# 31            Calvin Harris
# 32                 Maroon 5
# ...

# %%
# COUNTRY
USER_AGENT='Dataquest'
API_KEY= '0e183e26124cc0cca49ce5e97cad2811'

def chart_list_artist(country):    

    headers = {'user-agent': 'Dataquest'}
    payload = {'api_key': API_KEY,
        'method': 'geo.getTopArtists',
        'format': 'json',
        'country': country
    }
    r = requests.get('http://ws.audioscrobbler.com/2.0/', headers=headers, params=payload)
    result=r.json()

    country_list=[]
    for i in range (len(result['topartists']['artist'])):
                    country_list.append(result['topartists']['artist'][i]['name'])
    df=pd.DataFrame(country_list)
        
    return df
df=chart_list_artist('Switzerland')
df
# Out:
#                          0
# 0                 Coldplay
# 1                    Queen
# 2              David Bowie
# 3              The Beatles
# 4                Radiohead
# 5               Ed Sheeran
# 6                    Adele
# 7       The Rolling Stones
# 8    Red Hot Chili Peppers
# 9               Pink Floyd
# 10         Michael Jackson
# 11                     Sia
# 12                    Muse
# 13               Bob Dylan
# 14               Daft Punk
# 15                      U2
# 16                 Nirvana
# 17         Imagine Dragons
# 18           Calvin Harris
# 19            Lana Del Rey
# 20                 Rihanna
# 21           Stevie Wonder
# 22             Johnny Cash
# 23                Bon Iver
# 24                  The xx
# 25              The Weeknd
# 26  Florence + the Machine
# 27          Mumford & Sons
# 28             Major Lazer
# 29             Marvin Gaye
# 30            Led Zeppelin
# 31                  Eminem
# 32           Elvis Presley
# ...

# %%
df.columns=['artist']
df['country']='Switzerland'
df.insert(0, 'rank', range(1, 1 + len(df)))

df
# Out:
#     rank                  artist      country
# 0      1                Coldplay  Switzerland
# 1      2                   Queen  Switzerland
# 2      3             David Bowie  Switzerland
# 3      4             The Beatles  Switzerland
# 4      5               Radiohead  Switzerland
# 5      6              Ed Sheeran  Switzerland
# 6      7                   Adele  Switzerland
# 7      8      The Rolling Stones  Switzerland
# 8      9   Red Hot Chili Peppers  Switzerland
# 9     10              Pink Floyd  Switzerland
# 10    11         Michael Jackson  Switzerland
# 11    12                     Sia  Switzerland
# 12    13                    Muse  Switzerland
# 13    14               Bob Dylan  Switzerland
# 14    15               Daft Punk  Switzerland
# 15    16                      U2  Switzerland
# 16    17                 Nirvana  Switzerland
# 17    18         Imagine Dragons  Switzerland
# 18    19           Calvin Harris  Switzerland
# ...

# %%
df.to_csv('top_artist_cuba.csv', sep=',')

# %%
# TAGS
USER_AGENT='Dataquest'
API_KEY= '0e183e26124cc0cca49ce5e97cad2811'

headers = {'user-agent': 'Dataquest'}
payload = {'api_key': API_KEY,
    'method': 'chart.gettoptags',
    'format': 'json',
    'country': 'Spain'
}
r = requests.get('http://ws.audioscrobbler.com/2.0/', headers=headers, params=payload)
result=r.json()

# %%
tags_list=[]
for i in range (len(result['tags']['tag'])):
                tags_list.append(result['tags']['tag'][i]['name'])
print(tags_list)
# Out:
# ['rock', 'electronic', 'seen live', 'alternative', 'indie', 'pop', 'female vocalists', 'metal', 'alternative rock', 'jazz', 'classic rock', 'ambient', 'experimental', 'folk', 'punk', 'indie rock', 'hard rock', 'Hip-Hop', 'instrumental', 'singer-songwriter', 'black metal', 'dance', '80s', 'Progressive rock', 'death metal', 'heavy metal', 'hardcore', 'british', 'soul', 'chillout', 'electronica', 'Classical', 'industrial', 'rap', 'Soundtrack', 'blues', 'punk rock', 'thrash metal', '90s', 'acoustic', 'metalcore', 'psychedelic', 'japanese', 'post-rock', 'german', 'Progressive metal', 'hip hop', 'funk', 'new wave', 'trance']

# %%
df=pd.DataFrame(tags_list)
df.columns=['tags']
df.insert(0, 'rank', range(1, 1 + len(df)))

df
# Out:
#     rank               tags
# 0      1               rock
# 1      2         electronic
# 2      3          seen live
# 3      4        alternative
# 4      5              indie
# 5      6                pop
# 6      7   female vocalists
# 7      8              metal
# 8      9   alternative rock
# 9     10               jazz
# 10    11       classic rock
# 11    12            ambient
# 12    13       experimental
# 13    14               folk
# 14    15               punk
# 15    16         indie rock
# 16    17          hard rock
# 17    18            Hip-Hop
# 18    19       instrumental
# 19    20  singer-songwriter
# 20    21        black metal
# 21    22              dance
# 22    23                80s
# 23    24   Progressive rock
# 24    25        death metal
# 25    26        heavy metal
# 26    27           hardcore
# 27    28            british
# 28    29               soul
# 29    30           chillout
# 30    31        electronica
# 31    32          Classical
# ...

# %%
df.to_csv('top_tags.csv', sep=',')

# %%
from sqlalchemy import create_engine

# %%
driver   = 'mysql+pymysql:'
user     = 'guest'
password = 'Ironhack1234'
ip       = '35.195.172.42'
database = 'data_thieves'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string)

# %%
import pafy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pafy/pafy.py in <module>
#      47     try:
# ---> 48         import youtube_dl
#      49         backend = "youtube-dl"
#
# ModuleNotFoundError: No module named 'youtube_dl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-2bd8ef15b399> in <module>
# ----> 1 import pafy
#
# ~/anaconda3/lib/python3.7/site-packages/pafy/__init__.py in <module>
#       5
#       6 # External api
# ----> 7 from .pafy import new
#       8 from .pafy import set_api_key
#       9 from .pafy import load_cache, dump_cache
#
# ~/anaconda3/lib/python3.7/site-packages/pafy/pafy.py in <module>
#      50     except ImportError:
#      51         raise ImportError(
# ...

# %%
import pafy

# %%
import vlc
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-0eee96c7df58> in <module>
# ----> 1 import vlc
#
# ~/anaconda3/lib/python3.7/site-packages/vlc.py in <module>
#     205
#     206 # plugin_path used on win32 and MacOS in override.py
# --> 207 dll, plugin_path  = find_lib()
#     208
#     209 class VLCException(Exception):
#
# ~/anaconda3/lib/python3.7/site-packages/vlc.py in find_lib()
#     186         else:  # hope, some [DY]LD_LIBRARY_PATH is set...
#     187             # pre-load libvlccore VLC 2.2.8+
# --> 188             ctypes.CDLL('libvlccore.dylib')
#     189             dll = ctypes.CDLL('libvlc.dylib')
#     190
#
# ~/anaconda3/lib/python3.7/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     354
#     355         if handle is None:
# --> 356             self._handle = _dlopen(self._name, mode)
# ...

# %%
import pafy
import vlc

url = "https://www.youtube.com/watch?v=bMt47wvK6u0"
video = pafy.new(url)
best = video.getbest()
playurl = best.url
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-a9a70449358b> in <module>
#       1 import pafy
# ----> 2 import vlc
#       3
#       4 url = "https://www.youtube.com/watch?v=bMt47wvK6u0"
#       5 video = pafy.new(url)
#
# ~/anaconda3/lib/python3.7/site-packages/vlc.py in <module>
#     205
#     206 # plugin_path used on win32 and MacOS in override.py
# --> 207 dll, plugin_path  = find_lib()
#     208
#     209 class VLCException(Exception):
#
# ~/anaconda3/lib/python3.7/site-packages/vlc.py in find_lib()
#     186         else:  # hope, some [DY]LD_LIBRARY_PATH is set...
#     187             # pre-load libvlccore VLC 2.2.8+
# --> 188             ctypes.CDLL('libvlccore.dylib')
#     189             dll = ctypes.CDLL('libvlc.dylib')
#     190
#
# ~/anaconda3/lib/python3.7/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
# ...

# %%
playurl

# %%
import pafy
