# %%
import requests
import pandas as pd
import json

# %%
USER_AGENT='Dataquest'
API_KEY= '0e183e26124cc0cca49ce5e97cad2811'

headers = {'user-agent': 'Dataquest'}
payload = {'api_key': API_KEY,
    'method': 'chart.gettopartists',
    'format': 'json',
    'country': 'Spain'
}
r = requests.get('http://ws.audioscrobbler.com/2.0/', headers=headers, params=payload)
result=r.json()

# %%
result['artists']['artist'][1]['name']
# Out:
# 'The Weeknd'

# %%
artist_list=[]
for i in range (len(result['artists']['artist'])):
                artist_list.append(result['artists']['artist'][i]['name'])
print(artist_list)
# Out:
# ['Billie Eilish', 'The Weeknd', 'Eminem', 'Kanye West', 'Post Malone', 'Ariana Grande', 'Lana Del Rey', 'Tame Impala', 'Dua Lipa', 'Halsey', 'Kendrick Lamar', 'Radiohead', 'The Beatles', 'Queen', 'Drake', 'David Bowie', 'Taylor Swift', 'Ed Sheeran', 'Rihanna', 'Tyler, the Creator', 'Frank Ocean', 'Coldplay', 'Selena Gomez', 'Mac Miller', 'Arctic Monkeys', 'Harry Styles', 'Lady Gaga', 'Travi$ Scott', 'Gorillaz', 'Beyoncé', 'Justin Bieber', 'Red Hot Chili Peppers', 'Calvin Harris', 'Maroon 5', 'Lorde', 'Pink Floyd', 'BROCKHAMPTON', 'Katy Perry', 'Miley Cyrus', 'Green Day', 'Childish Gambino', 'Nirvana', 'Fleetwood Mac', 'Panic! at the Disco', 'Lizzo', 'Future', 'Khalid', 'Imagine Dragons', 'Camila Cabello', 'Sia']

# %%
serie_artists=pd.Series(artist_list)
serie_artists
# Out:
# 0             Billie Eilish
# 1                The Weeknd
# 2                    Eminem
# 3                Kanye West
# 4               Post Malone
# 5             Ariana Grande
# 6              Lana Del Rey
# 7               Tame Impala
# 8                  Dua Lipa
# 9                    Halsey
# 10           Kendrick Lamar
# 11                Radiohead
# 12              The Beatles
# 13                    Queen
# 14                    Drake
# 15              David Bowie
# 16             Taylor Swift
# 17               Ed Sheeran
# 18                  Rihanna
# 19       Tyler, the Creator
# 20              Frank Ocean
# 21                 Coldplay
# 22             Selena Gomez
# 23               Mac Miller
# 24           Arctic Monkeys
# 25             Harry Styles
# 26                Lady Gaga
# 27             Travi$ Scott
# 28                 Gorillaz
# 29                  Beyoncé
# 30            Justin Bieber
# 31    Red Hot Chili Peppers
# 32            Calvin Harris
# 33                 Maroon 5
# 34                    Lorde
# 35               Pink Floyd
# 36             BROCKHAMPTON
# 37               Katy Perry
# 38              Miley Cyrus
# 39                Green Day
# 40         Childish Gambino
# 41                  Nirvana
# 42            Fleetwood Mac
# 43      Panic! at the Disco
# 44                    Lizzo
# 45                   Future
# 46                   Khalid
# 47          Imagine Dragons
# 48           Camila Cabello
# 49                      Sia
# dtype: object

# %%
# COUNTRY
USER_AGENT='Dataquest'
API_KEY= '0e183e26124cc0cca49ce5e97cad2811'

def chart_list_artist(country):    

    headers = {'user-agent': 'Dataquest'}
    payload = {'api_key': API_KEY,
        'method': 'geo.getTopArtists',
        'format': 'json',
        'country': country
    }
    r = requests.get('http://ws.audioscrobbler.com/2.0/', headers=headers, params=payload)
    result=r.json()

    country_list=[]
    for i in range (len(result['topartists']['artist'])):
                    country_list.append(result['topartists']['artist'][i]['name'])
    df=pd.DataFrame(country_list)
        
    return df
df=chart_list_artist('Cuba')
df
# Out:
#                                0
# 0                    The Beatles
# 1                        Nirvana
# 2                      Daft Punk
# 3                             U2
# 4                            Sia
# 5                  Fleetwood Mac
# 6              Justin Timberlake
# 7                     Elton John
# 8                     The Police
# 9                   Jason Derülo
# 10                       Cardi B
# 11                Arctic Monkeys
# 12                      Coldplay
# 13                    Kanye West
# 14                  Lana Del Rey
# 15         Red Hot Chili Peppers
# 16                        Eminem
# 17                 Ariana Grande
# 18                   The Killers
# 19                  Foo Fighters
# 20                   Arcade Fire
# 21               Nine Inch Nails
# 22                      The Cure
# 23            The Rolling Stones
# 24       Queens of the Stone Age
# 25                     Pearl Jam
# 26                     The Doors
# 27                    Ed Sheeran
# 28         The Smashing Pumpkins
# 29                    The Weeknd
# 30                Marilyn Manson
# 31             The White Stripes
# 32                        Weezer
# 33                 Black Sabbath
# 34                  David Guetta
# 35                        R.E.M.
# 36      Rage Against the Machine
# 37                  Beastie Boys
# 38                  Selena Gomez
# 39  Creedence Clearwater Revival
# 40                      Dua Lipa
# 41                    Disclosure
# 42                        Future
# 43              The Chainsmokers
# 44                Paul McCartney
# 45                   Fatboy Slim
# 46                 Lenny Kravitz
# 47                  Charlie Puth
# 48                       Rosalía
# 49                 The Jackson 5

# %%
df.columns=['artist']
df['country']='Cuba'
df.insert(0, 'rank', range(1, 1 + len(df)))

df
# Out:
#     rank                        artist country
# 0      1                   The Beatles    Cuba
# 1      2                       Nirvana    Cuba
# 2      3                     Daft Punk    Cuba
# 3      4                            U2    Cuba
# 4      5                           Sia    Cuba
# 5      6                 Fleetwood Mac    Cuba
# 6      7             Justin Timberlake    Cuba
# 7      8                    Elton John    Cuba
# 8      9                    The Police    Cuba
# 9     10                  Jason Derülo    Cuba
# 10    11                       Cardi B    Cuba
# 11    12                Arctic Monkeys    Cuba
# 12    13                      Coldplay    Cuba
# 13    14                    Kanye West    Cuba
# 14    15                  Lana Del Rey    Cuba
# 15    16         Red Hot Chili Peppers    Cuba
# 16    17                        Eminem    Cuba
# 17    18                 Ariana Grande    Cuba
# 18    19                   The Killers    Cuba
# 19    20                  Foo Fighters    Cuba
# 20    21                   Arcade Fire    Cuba
# 21    22               Nine Inch Nails    Cuba
# 22    23                      The Cure    Cuba
# 23    24            The Rolling Stones    Cuba
# 24    25       Queens of the Stone Age    Cuba
# 25    26                     Pearl Jam    Cuba
# 26    27                     The Doors    Cuba
# 27    28                    Ed Sheeran    Cuba
# 28    29         The Smashing Pumpkins    Cuba
# 29    30                    The Weeknd    Cuba
# 30    31                Marilyn Manson    Cuba
# 31    32             The White Stripes    Cuba
# 32    33                        Weezer    Cuba
# 33    34                 Black Sabbath    Cuba
# 34    35                  David Guetta    Cuba
# 35    36                        R.E.M.    Cuba
# 36    37      Rage Against the Machine    Cuba
# 37    38                  Beastie Boys    Cuba
# 38    39                  Selena Gomez    Cuba
# 39    40  Creedence Clearwater Revival    Cuba
# 40    41                      Dua Lipa    Cuba
# 41    42                    Disclosure    Cuba
# 42    43                        Future    Cuba
# 43    44              The Chainsmokers    Cuba
# 44    45                Paul McCartney    Cuba
# 45    46                   Fatboy Slim    Cuba
# 46    47                 Lenny Kravitz    Cuba
# 47    48                  Charlie Puth    Cuba
# 48    49                       Rosalía    Cuba
# 49    50                 The Jackson 5    Cuba

# %%
df.to_csv('top_artist_cuba.csv', sep=',')

# %%
# TAGS
USER_AGENT='Dataquest'
API_KEY= '0e183e26124cc0cca49ce5e97cad2811'

headers = {'user-agent': 'Dataquest'}
payload = {'api_key': API_KEY,
    'method': 'chart.gettoptags',
    'format': 'json',
    'country': 'Spain'
}
r = requests.get('http://ws.audioscrobbler.com/2.0/', headers=headers, params=payload)
result=r.json()

# %%
tags_list=[]
for i in range (len(result['tags']['tag'])):
                tags_list.append(result['tags']['tag'][i]['name'])
print(tags_list)
# Out:
# ['rock', 'electronic', 'seen live', 'alternative', 'indie', 'pop', 'female vocalists', 'metal', 'alternative rock', 'jazz', 'classic rock', 'ambient', 'experimental', 'folk', 'punk', 'indie rock', 'hard rock', 'Hip-Hop', 'instrumental', 'singer-songwriter', 'black metal', 'dance', '80s', 'Progressive rock', 'death metal', 'heavy metal', 'hardcore', 'british', 'soul', 'chillout', 'electronica', 'Classical', 'industrial', 'rap', 'Soundtrack', 'blues', 'punk rock', 'thrash metal', '90s', 'acoustic', 'metalcore', 'psychedelic', 'japanese', 'post-rock', 'german', 'Progressive metal', 'hip hop', 'funk', 'new wave', 'trance']

# %%
df=pd.DataFrame(tags_list)
df.columns=['tags']
df.insert(0, 'rank', range(1, 1 + len(df)))

df
# Out:
#     rank               tags
# 0      1               rock
# 1      2         electronic
# 2      3          seen live
# 3      4        alternative
# 4      5              indie
# 5      6                pop
# 6      7   female vocalists
# 7      8              metal
# 8      9   alternative rock
# 9     10               jazz
# 10    11       classic rock
# 11    12            ambient
# 12    13       experimental
# 13    14               folk
# 14    15               punk
# 15    16         indie rock
# 16    17          hard rock
# 17    18            Hip-Hop
# 18    19       instrumental
# 19    20  singer-songwriter
# 20    21        black metal
# 21    22              dance
# 22    23                80s
# 23    24   Progressive rock
# 24    25        death metal
# 25    26        heavy metal
# 26    27           hardcore
# 27    28            british
# 28    29               soul
# 29    30           chillout
# 30    31        electronica
# 31    32          Classical
# 32    33         industrial
# 33    34                rap
# 34    35         Soundtrack
# 35    36              blues
# 36    37          punk rock
# 37    38       thrash metal
# 38    39                90s
# 39    40           acoustic
# 40    41          metalcore
# 41    42        psychedelic
# 42    43           japanese
# 43    44          post-rock
# 44    45             german
# 45    46  Progressive metal
# 46    47            hip hop
# 47    48               funk
# 48    49           new wave
# 49    50             trance

# %%
df.to_csv('top_tags.csv', sep=',')

# %%
from sqlalchemy import create_engine

# %%
driver   = 'mysql+pymysql:'
user     = 'guest'
password = 'Ironhack1234'
ip       = '35.195.172.42'
database = 'data_thieves'
connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string)
